# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 44.6 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="QwexQt61txljwWZofazB")
project = rf.workspace("food-w4zm1").project("recipe-ingredients-2")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Recipe-Ingredients-2-3 in yolov8:: 100%|██████████| 31336/31336 [00:05<00:00, 5864.27it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO

model_fp32 = YOLO(
    "/content/best_float32.tflite"
)

metrics_fp32 = model_fp32.val(
    data="/content/Recipe-Ingredients-2-3/data.yaml"
)

print("FP32 mAP50:", metrics_fp32.box.map50)
print("FP32 mAP50-95:", metrics_fp32.box.map)
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.4.59 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Loading /content/best_float32.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 640, 640)
# ...
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1297.8±660.5 MB/s, size: 39.8 KB)
# val: Scanning /content/Recipe-Ingredients-2-3/valid/labels... 794 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 794/794 1.8Kit/s 0.4s
# val: New cache created: /content/Recipe-Ingredients-2-3/valid/labels.cache
# ...

# %%
model_int8 = YOLO(
    "/content/best_int8.tflite"
)

metrics_int8 = model_int8.val(
    data="/content/Recipe-Ingredients-2-3/data.yaml"
)

print("INT8 mAP50:", metrics_int8.box.map50)
print("INT8 mAP50-95:", metrics_int8.box.map)
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.4.59 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Loading /content/best_int8.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 640, 640)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1638.8±383.2 MB/s, size: 48.2 KB)
# val: Scanning /content/Recipe-Ingredients-2-3/valid/labels.cache... 794 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 794/794 256.2Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 12, len(boxes) = 10208. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# ...
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
# ...
